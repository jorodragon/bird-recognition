# %% [markdown]
# # Dataset split
#
# This file divides our dataset into train, validation and test set. We can't use preprogrammed functions to do that, because we divided each of our files into other smallers (i.e. one sound to six images). Putting images made out of same mp3 file might lead to the *data leakage* and make our results *not trustworthy* and *biased*.

# %%
import os

# define number of files for all sets
train = 0.8 # 80% of all sound should be in the train set
val = 0.1 # 10% validation set
test = 0.1 # 10% test set
kfolds = 1
basePath="/Volumes/MacDATA/LEARNING/thesis/bird-recognition/core-ai/data/full/" # path with sound files. Can be downloaded with "AM_downloadData"
imPath = "/Volumes/MacDATA/LEARNING/thesis/bird-recognition/core-ai/data/full-mels/" # path with images (melspectrograms)
                                # Can be generated with "AM_prepareData" after downloading sound files
destPath = "/Volumes/MacDATA/LEARNING/thesis/bird-recognition/core-ai/data/full-data/" # destination path - where the split dataset should be copied
                            # This folder will be used to train CNNs

# first find all of the mp3 files in the directory
birds=[] # list of all bird spiecies (Ember, Phyll...)
singleBirdList=[] # list of files for one bird
allFilesList=[] # list of all files for all birds. A list of singleBirdLists. 
for root, dirs, files in os.walk(imPath):
    if root == imPath:
        birds=dirs
print(birds)

trainSet=[]
testSet=[]
valSet=[]

birdsShort=[] # list of short file names
birdNumber=0
for nr,bird in enumerate(birds):
    for root, dirs, files in os.walk(imPath+bird):
        for file in files:
            if file.endswith(".png"):
                singleBirdList.append(os.path.join(root, file))
    birdsShort.append(str(birdNumber)+bird)
    birdNumber = birdNumber+1;
    print("Found ", len(singleBirdList), ' mp3 files for ', bird)
    trainSet.append(int(train*len(singleBirdList)))
    valSet.append(int(val*len(singleBirdList)))
    roundDiff = len(singleBirdList)-(int(train*len(singleBirdList))+int(test*len(singleBirdList))+int(val*len(singleBirdList))) 
    testSet.append(int(test*len(singleBirdList)) + roundDiff)
    print("Size of train: ", int(train*len(singleBirdList)),", val: ",int(val*len(singleBirdList)) ,", test: ",int(test*len(singleBirdList)))
    allFilesList.append(singleBirdList)
    singleBirdList=[]


print(trainSet)
print(valSet)
print(testSet)
# Out:
# ['se', 'hoang-yen', 'hoa-mi', 'tri', 'trich-co', 'hoet-lua', 'le-le', 'sao-nau', 'cu-dat', 'chich-choe', 'cong-coc', 'ca-cuong', 'co', 'quoc', 'hec-xoan', 'hoet-den', 'phuong-hoang-dat', 'oanh', 'huyt-co', 'khuou', 'trich-re', 'chang-nghich', 'mo-nhat', 'de-giun', 'khuyen', 'bim-bip', 'chao-mao', 'hut-mat', 'cheo-beo', 'cut', 'sau', 'cum-num', 'thanh-lam', 'bo-cau', 'choc-quach', 'que-lam', 'ngu-sac', 'hoanh-hoach', 'en', 'thanh-tuoc', 'vac', 'chia-voi', 'mat-xeo', 'mat-do', 'sam-cam', 'cu-gay', 'ket', 'trao-trao', 'xanh-tim']
# Found  831  mp3 files for  se
# Size of train:  664 , val:  83 , test:  83
# Found  169  mp3 files for  hoang-yen
# Size of train:  135 , val:  16 , test:  16
# Found  543  mp3 files for  hoa-mi
# Size of train:  434 , val:  54 , test:  54
# Found  123  mp3 files for  tri
# Size of train:  98 , val:  12 , test:  12
# Found  172  mp3 files for  trich-co
# Size of train:  137 , val:  17 , test:  17
# Found  184  mp3 files for  hoet-lua
# Size of train:  147 , val:  18 , test:  18
# Found  147  mp3 files for  le-le
# Size of train:  117 , val:  14 , test:  14
# Found  273  mp3 files for  sao-nau
# Size of train:  218 , val:  27 , test:  27
# Found  268  mp3 files for  cu-dat
# Size of train:  214 , val:  26 , test:  26
# Found  796  mp3 files for  chich-choe
# Size of train:  636 , val:  79 , test:  79
# Found  99  mp3 files for  cong-coc
# Size of train:  79 , val:  9 , test:  9
# Found  86  mp3 files for  ca-cuong
# Size of train:  68 , val:  8 , test:  8
# Found  135  mp3 files for  co
# Size of train:  108 , val:  13 , test:  13
# Found  511  mp3 files for  quoc
# Size of train:  408 , val:  51 , test:  51
# Found  172  mp3 files for  hec-xoan
# Size of train:  137 , val:  17 , test:  17
# Found  271  mp3 files for  hoet-den
# Size of train:  216 , val:  27 , test:  27
# Found  146  mp3 files for  phuong-hoang-dat
# Size of train:  116 , val:  14 , test:  14
# Found  176  mp3 files for  oanh
# Size of train:  140 , val:  17 , test:  17
# Found  169  mp3 files for  huyt-co
# Size of train:  135 , val:  16 , test:  16
# Found  941  mp3 files for  khuou
# Size of train:  752 , val:  94 , test:  94
# Found  536  mp3 files for  trich-re
# Size of train:  428 , val:  53 , test:  53
# Found  120  mp3 files for  chang-nghich
# Size of train:  96 , val:  12 , test:  12
# Found  185  mp3 files for  mo-nhat
# Size of train:  148 , val:  18 , test:  18
# Found  531  mp3 files for  de-giun
# Size of train:  424 , val:  53 , test:  53
# Found  515  mp3 files for  khuyen
# Size of train:  412 , val:  51 , test:  51
# Found  667  mp3 files for  bim-bip
# Size of train:  533 , val:  66 , test:  66
# Found  1316  mp3 files for  chao-mao
# Size of train:  1052 , val:  131 , test:  131
# Found  247  mp3 files for  hut-mat
# Size of train:  197 , val:  24 , test:  24
# Found  237  mp3 files for  cheo-beo
# Size of train:  189 , val:  23 , test:  23
# Found  740  mp3 files for  cut
# Size of train:  592 , val:  74 , test:  74
# Found  437  mp3 files for  sau
# Size of train:  349 , val:  43 , test:  43
# Found  132  mp3 files for  cum-num
# Size of train:  105 , val:  13 , test:  13
# Found  145  mp3 files for  thanh-lam
# Size of train:  116 , val:  14 , test:  14
# Found  97  mp3 files for  bo-cau
# Size of train:  77 , val:  9 , test:  9
# Found  97  mp3 files for  choc-quach
# Size of train:  77 , val:  9 , test:  9
# Found  97  mp3 files for  que-lam
# Size of train:  77 , val:  9 , test:  9
# Found  122  mp3 files for  ngu-sac
# Size of train:  97 , val:  12 , test:  12
# Found  131  mp3 files for  hoanh-hoach
# Size of train:  104 , val:  13 , test:  13
# Found  195  mp3 files for  en
# Size of train:  156 , val:  19 , test:  19
# Found  177  mp3 files for  thanh-tuoc
# Size of train:  141 , val:  17 , test:  17
# Found  168  mp3 files for  vac
# Size of train:  134 , val:  16 , test:  16
# Found  90  mp3 files for  chia-voi
# Size of train:  72 , val:  9 , test:  9
# Found  171  mp3 files for  mat-xeo
# Size of train:  136 , val:  17 , test:  17
# Found  169  mp3 files for  mat-do
# Size of train:  135 , val:  16 , test:  16
# Found  173  mp3 files for  sam-cam
# Size of train:  138 , val:  17 , test:  17
# Found  478  mp3 files for  cu-gay
# Size of train:  382 , val:  47 , test:  47
# Found  97  mp3 files for  ket
# Size of train:  77 , val:  9 , test:  9
# Found  430  mp3 files for  trao-trao
# Size of train:  344 , val:  43 , test:  43
# Found  172  mp3 files for  xanh-tim
# Size of train:  137 , val:  17 , test:  17
# [664, 135, 434, 98, 137, 147, 117, 218, 214, 636, 79, 68, 108, 408, 137, 216, 116, 140, 135, 752, 428, 96, 148, 424, 412, 533, 1052, 197, 189, 592, 349, 105, 116, 77, 77, 77, 97, 104, 156, 141, 134, 72, 136, 135, 138, 382, 77, 344, 137]
# [83, 16, 54, 12, 17, 18, 14, 27, 26, 79, 9, 8, 13, 51, 17, 27, 14, 17, 16, 94, 53, 12, 18, 53, 51, 66, 131, 24, 23, 74, 43, 13, 14, 9, 9, 9, 12, 13, 19, 17, 16, 9, 17, 16, 17, 47, 9, 43, 17]
# [84, 18, 55, 13, 18, 19, 16, 28, 28, 81, 11, 10, 14, 52, 18, 28, 16, 19, 18, 95, 55, 12, 19, 54, 52, 68, 133, 26, 25, 74, 45, 14, 15, 11, 11, 11, 13, 14, 20, 19, 18, 9, 18, 18, 18, 49, 11, 43, 18]

# %%
# randomly choose mp3 files for each set  

from random import sample

trainFiles=[]
valFiles=[]
testFiles=[]

for index, singleBirdList in enumerate(allFilesList):
    randFiles = sample(range(len(singleBirdList)), len(singleBirdList))
    start = 0
    end = trainSet[index]
    trainFiles.append(randFiles[start:end])
    start = end 
    end = start + valSet[index]
    valFiles.append(randFiles[start:end])
    start = end 
    end = start + testSet[index] 
    testFiles.append(randFiles[start:end])
    print("Selected random files number:\n train: ", len(trainFiles[index]),"/",trainSet[index],
          ", val: ",len(valFiles[index]),"/",valSet[index],
          ", test: ",len(testFiles[index]),"/",testSet[index])
# Out:
# Selected random files number:
#  train:  664 / 664 , val:  83 / 83 , test:  84 / 84
# Selected random files number:
#  train:  135 / 135 , val:  16 / 16 , test:  18 / 18
# Selected random files number:
#  train:  434 / 434 , val:  54 / 54 , test:  55 / 55
# Selected random files number:
#  train:  98 / 98 , val:  12 / 12 , test:  13 / 13
# Selected random files number:
#  train:  137 / 137 , val:  17 / 17 , test:  18 / 18
# Selected random files number:
#  train:  147 / 147 , val:  18 / 18 , test:  19 / 19
# Selected random files number:
#  train:  117 / 117 , val:  14 / 14 , test:  16 / 16
# Selected random files number:
#  train:  218 / 218 , val:  27 / 27 , test:  28 / 28
# Selected random files number:
#  train:  214 / 214 , val:  26 / 26 , test:  28 / 28
# Selected random files number:
#  train:  636 / 636 , val:  79 / 79 , test:  81 / 81
# Selected random files number:
#  train:  79 / 79 , val:  9 / 9 , test:  11 / 11
# Selected random files number:
#  train:  68 / 68 , val:  8 / 8 , test:  10 / 10
# Selected random files number:
#  train:  108 / 108 , val:  13 / 13 , test:  14 / 14
# Selected random files number:
#  train:  408 / 408 , val:  51 / 51 , test:  52 / 52
# Selected random files number:
#  train:  137 / 137 , val:  17 / 17 , test:  18 / 18
# Selected random files number:
#  train:  216 / 216 , val:  27 / 27 , test:  28 / 28
# Selected random files number:
#  train:  116 / 116 , val:  14 / 14 , test:  16 / 16
# Selected random files number:
#  train:  140 / 140 , val:  17 / 17 , test:  19 / 19
# Selected random files number:
#  train:  135 / 135 , val:  16 / 16 , test:  18 / 18
# Selected random files number:
#  train:  752 / 752 , val:  94 / 94 , test:  95 / 95
# Selected random files number:
#  train:  428 / 428 , val:  53 / 53 , test:  55 / 55
# Selected random files number:
#  train:  96 / 96 , val:  12 / 12 , test:  12 / 12
# Selected random files number:
#  train:  148 / 148 , val:  18 / 18 , test:  19 / 19
# Selected random files number:
#  train:  424 / 424 , val:  53 / 53 , test:  54 / 54
# Selected random files number:
#  train:  412 / 412 , val:  51 / 51 , test:  52 / 52
# Selected random files number:
#  train:  533 / 533 , val:  66 / 66 , test:  68 / 68
# Selected random files number:
#  train:  1052 / 1052 , val:  131 / 131 , test:  133 / 133
# Selected random files number:
#  train:  197 / 197 , val:  24 / 24 , test:  26 / 26
# Selected random files number:
#  train:  189 / 189 , val:  23 / 23 , test:  25 / 25
# Selected random files number:
#  train:  592 / 592 , val:  74 / 74 , test:  74 / 74
# Selected random files number:
#  train:  349 / 349 , val:  43 / 43 , test:  45 / 45
# Selected random files number:
#  train:  105 / 105 , val:  13 / 13 , test:  14 / 14
# Selected random files number:
#  train:  116 / 116 , val:  14 / 14 , test:  15 / 15
# Selected random files number:
#  train:  77 / 77 , val:  9 / 9 , test:  11 / 11
# Selected random files number:
#  train:  77 / 77 , val:  9 / 9 , test:  11 / 11
# Selected random files number:
#  train:  77 / 77 , val:  9 / 9 , test:  11 / 11
# Selected random files number:
#  train:  97 / 97 , val:  12 / 12 , test:  13 / 13
# Selected random files number:
#  train:  104 / 104 , val:  13 / 13 , test:  14 / 14
# Selected random files number:
#  train:  156 / 156 , val:  19 / 19 , test:  20 / 20
# Selected random files number:
#  train:  141 / 141 , val:  17 / 17 , test:  19 / 19
# Selected random files number:
#  train:  134 / 134 , val:  16 / 16 , test:  18 / 18
# Selected random files number:
#  train:  72 / 72 , val:  9 / 9 , test:  9 / 9
# Selected random files number:
#  train:  136 / 136 , val:  17 / 17 , test:  18 / 18
# Selected random files number:
#  train:  135 / 135 , val:  16 / 16 , test:  18 / 18
# Selected random files number:
#  train:  138 / 138 , val:  17 / 17 , test:  18 / 18
# Selected random files number:
#  train:  382 / 382 , val:  47 / 47 , test:  49 / 49
# Selected random files number:
#  train:  77 / 77 , val:  9 / 9 , test:  11 / 11
# Selected random files number:
#  train:  344 / 344 , val:  43 / 43 , test:  43 / 43
# Selected random files number:
#  train:  137 / 137 , val:  17 / 17 , test:  18 / 18

# %% [markdown]
# # Copying files to a new directory
# In previous blocks we've randomly selected which files will belong to which sets. Now we have to find corresponding images to those files and copy them to new directory.
#
# * new directory - i.e. ..data/mels/final
#     - train
#         - one folder for each class
#         - Ember
#         - Phyll
#         - ...
#     - val
#         - folders for each class
#     - test
#         - folders for each class

# %%
def extractName(string):
    return string.rsplit('/',1)[1].replace(' ', '')[:-4]

# %%
# sort all the lists to make copying files easier
sets=[trainFiles,valFiles,testFiles]
for fileSet in sets:
    for index,files in enumerate(fileSet):
        fileSet[index].sort()

# %%
# change full names to short

for root, dirs, files in os.walk(basePath):
    if root == basePath:
        birds=dirs
#birdsShort=[]
#for bird in birds:
#    birdsShort.append(bird[:5])

setNames = ["train/","val/","test/"]

print("Long: ", birds,"\nShort: ",birdsShort)
# Out:
# Long:  ['se', 'hoang-yen', 'hoa-mi', 'tri', 'trich-co', 'hoet-lua', 'le-le', 'sao-nau', 'cu-dat', 'chich-choe', 'cong-coc', 'ca-cuong', 'co', 'quoc', 'hec-xoan', 'hoet-den', 'phuong-hoang-dat', 'oanh', 'huyt-co', 'khuou', 'trich-re', 'chang-nghich', 'mo-nhat', 'de-giun', 'khuyen', 'bim-bip', 'chao-mao', 'hut-mat', 'cheo-beo', 'cut', 'sau', 'cum-num', 'thanh-lam', 'bo-cau', 'choc-quach', 'que-lam', 'ngu-sac', 'hoanh-hoach', 'en', 'thanh-tuoc', 'vac', 'chia-voi', 'mat-xeo', 'mat-do', 'sam-cam', 'cu-gay', 'ket', 'trao-trao', 'xanh-tim']
# Short:  ['0se', '1hoang-yen', '2hoa-mi', '3tri', '4trich-co', '5hoet-lua', '6le-le', '7sao-nau', '8cu-dat', '9chich-choe', '10cong-coc', '11ca-cuong', '12co', '13quoc', '14hec-xoan', '15hoet-den', '16phuong-hoang-dat', '17oanh', '18huyt-co', '19khuou', '20trich-re', '21chang-nghich', '22mo-nhat', '23de-giun', '24khuyen', '25bim-bip', '26chao-mao', '27hut-mat', '28cheo-beo', '29cut', '30sau', '31cum-num', '32thanh-lam', '33bo-cau', '34choc-quach', '35que-lam', '36ngu-sac', '37hoanh-hoach', '38en', '39thanh-tuoc', '40vac', '41chia-voi', '42mat-xeo', '43mat-do', '44sam-cam', '45cu-gay', '46ket', '47trao-trao', '48xanh-tim']

# %%
import shutil

counter=0
for birdNumber, bird in enumerate(birdsShort): # for each class (bird) check where the file should be copied
    print(counter)
    counter=0
    for setName, fileSet in zip(setNames, sets): # check for all datasets: train, val and test sests 
        for setNumber in fileSet[birdNumber]:
            
            for fileNumber, file in enumerate(allFilesList[birdNumber]):
                if setNumber == fileNumber: # if file number to copy is same as number of file, then copy it
                    
                    for root, dirs, files in os.walk(imPath):
                        for file2 in files:
                            if extractName(file) in file2:
                                counter=counter+1
                                source=root+"/"+file2
                                
                                destination = destPath+setName+bird+"/"
                                if not os.path.exists(destination):
                                    os.makedirs(destination)
                                shutil.copy2(source, destination)
                                #print(source, "   ->   ", destination)
# Out:
# 0
# 831
# 169
# 543
# 123
# 172
# 184
# 147
# 273
# 268
# 796
# 99
# 86
# 259
# 511
# 172
# 271
# 146
# 176
# 169
# 941
# 536
# 120
# 185
# 531
# 515
# 667
# 1316
# 247
# 237
# 740
# 437
# 132
# 145
# 97
# 97
# 97
# 122
# 131
# 707
# 177
# 168
# 90
# 171
# 169
# 173
# 478
# 97
# 430
